# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import missingno as msno

# %%
import pandas as pd
# url = "/home/kiran/Documents/data_science/Scania-Truck-Failures/artifacts/local_data_dirs/aps_failure_training_set.csv"
url ="https://scania-failure-truck.s3.us-east-1.amazonaws.com/data/aps_failure_training_set.csv?response-content-disposition=inline&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEAkaCmFwLXNvdXRoLTEiRzBFAiEAltGcfU%2B8QwGPY8ls%2BtNjgHJyzm2X9FFbUvjmuce%2FZWUCIDVDdtEhAWUJ6hGcndnDoU6LXs4WfczomdImaxKoQvhkKv8CCPL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMNjg0Njc3OTA0NDg3IgyIDpHwvkluiotRBK4q0wLjRXvVEc2dw7D%2Fzp2IKDgb0ftUUodskj2wJ3hqCTDXz21BySIslEKfQ6X%2BRCsa4YV5DMGGqm5IqzKMt7m1PDvOIEs0TFQ90Dqh%2BMz3Vui4zPU16u1rMMGSKScl7gcsEVlDbrOE9HYpmNHGdTx00PoxAVwj5MDf66LbZbvti%2FmnwMTfvXRrCT13OuG4bpPUyABR7My8Ud0PzBdYos%2FuG38eP1D9PFZTd9153UKs%2BT1ybMSNXmRhgxFqb8Wo4WG%2FU7mnrCttFgDU2Wt%2FmZ3Fyb7dw12d8vCQ1yIWfhxOXOY6l7tz1hkC6zrIy8w%2BmXi%2FVkzmgHoL%2F5BaIKRqtwaJR%2F6vNvKzaDkZFXT3fGcAekj3sjSLNoOQRxMuJl4vu9Eu1CvETsYAYXKoYt9G%2BUI4iw0Gm8BUc%2B7OiHDVSlqQEPZ8YlV5OtRbj9d%2BtHcKv16JmeOhuA8w%2FeKCjgY6swJI3KuJYq2hTQDnvuCy4gapCOWMGiFcZg5eUbqCzrDNrv8oA2wuEN%2BBOusJuAtF25AbdJrEYMQPXpLZDKPOmJIhC%2BMTM0PfTmy5eMqBv44cZAlGEVNwTdkfK1ZvfDzKCOwno%2BxQKjw%2BIU7%2Fk5IF1gVZa5AbtczYSHpr%2B2sPH7dTnxBYVQ%2BM95wW6dO%2FgTRXNFUgj8BpuBGZkb5xkPVjsaJYq%2Ftng0926TC6PbDl1IouOmNPe3vTyI95Ky2qZYnRM0pV99%2FBSzScmWTEnZs%2BKWhiJ1p1KlaoBnV%2FkzYJr6vjXxdtIhjWB%2FBASvo9dG0wW3ZQkEis%2Fv7DdflF4qnsQsTkMiZyCsy2C%2BwL%2FhexuWBkaf7dJIiTmnNV4T06z07tV83oWttxbanO%2BVFFH8tTaoJzo6FX&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211220T165557Z&X-Amz-SignedHeaders=host&X-Amz-Expires=604800&X-Amz-Credential=ASIAZ62P3XBT6DKWXC7X%2F20211220%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=af3170a0deaf0cb5247bd618f1e0f49304f0d620e68064f46e18e1967e55eb5c"
df = pd.read_csv(url)
df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg   76698     na  2130706438    280      0      0      0      0
# 1       neg   33058     na           0     na      0      0      0      0
# 2       neg   41040     na         228    100      0      0      0      0
# 3       neg      12      0          70     66      0     10      0      0
# 4       neg   60874     na        1368    458      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 59995   neg  153002     na         664    186      0      0      0      0
# 59996   neg    2286     na  2130706538    224      0      0      0      0
# 59997   neg     112      0  2130706432     18      0      0      0      0
# 59998   neg   80292     na  2130706432    494      0      0      0      0
# 59999   neg   40222     na         698    628      0      0      0      0
#
#       ag_002  ...   ee_002  ee_003   ee_004   ee_005   ee_006  ee_007  ee_008  \
# ...

# %%
df.shape
# Out:
# (60000, 171)

# %%
import pandas as pd
# url = "/home/kiran/Documents/data_science/Scania-Truck-Failures/artifacts/local_data_dirs/aps_failure_test_set.csv"
url = "https://scania-failure-truck.s3.us-east-1.amazonaws.com/data/aps_failure_test_set.csv?response-content-disposition=inline&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEAkaCmFwLXNvdXRoLTEiRzBFAiEAltGcfU%2B8QwGPY8ls%2BtNjgHJyzm2X9FFbUvjmuce%2FZWUCIDVDdtEhAWUJ6hGcndnDoU6LXs4WfczomdImaxKoQvhkKv8CCPL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQABoMNjg0Njc3OTA0NDg3IgyIDpHwvkluiotRBK4q0wLjRXvVEc2dw7D%2Fzp2IKDgb0ftUUodskj2wJ3hqCTDXz21BySIslEKfQ6X%2BRCsa4YV5DMGGqm5IqzKMt7m1PDvOIEs0TFQ90Dqh%2BMz3Vui4zPU16u1rMMGSKScl7gcsEVlDbrOE9HYpmNHGdTx00PoxAVwj5MDf66LbZbvti%2FmnwMTfvXRrCT13OuG4bpPUyABR7My8Ud0PzBdYos%2FuG38eP1D9PFZTd9153UKs%2BT1ybMSNXmRhgxFqb8Wo4WG%2FU7mnrCttFgDU2Wt%2FmZ3Fyb7dw12d8vCQ1yIWfhxOXOY6l7tz1hkC6zrIy8w%2BmXi%2FVkzmgHoL%2F5BaIKRqtwaJR%2F6vNvKzaDkZFXT3fGcAekj3sjSLNoOQRxMuJl4vu9Eu1CvETsYAYXKoYt9G%2BUI4iw0Gm8BUc%2B7OiHDVSlqQEPZ8YlV5OtRbj9d%2BtHcKv16JmeOhuA8w%2FeKCjgY6swJI3KuJYq2hTQDnvuCy4gapCOWMGiFcZg5eUbqCzrDNrv8oA2wuEN%2BBOusJuAtF25AbdJrEYMQPXpLZDKPOmJIhC%2BMTM0PfTmy5eMqBv44cZAlGEVNwTdkfK1ZvfDzKCOwno%2BxQKjw%2BIU7%2Fk5IF1gVZa5AbtczYSHpr%2B2sPH7dTnxBYVQ%2BM95wW6dO%2FgTRXNFUgj8BpuBGZkb5xkPVjsaJYq%2Ftng0926TC6PbDl1IouOmNPe3vTyI95Ky2qZYnRM0pV99%2FBSzScmWTEnZs%2BKWhiJ1p1KlaoBnV%2FkzYJr6vjXxdtIhjWB%2FBASvo9dG0wW3ZQkEis%2Fv7DdflF4qnsQsTkMiZyCsy2C%2BwL%2FhexuWBkaf7dJIiTmnNV4T06z07tV83oWttxbanO%2BVFFH8tTaoJzo6FX&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211220T163856Z&X-Amz-SignedHeaders=host&X-Amz-Expires=604800&X-Amz-Credential=ASIAZ62P3XBT6DKWXC7X%2F20211220%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=de822b460b44b416d738b1259fc751abfcbdba0bcb4c0ec3d19b1fb3a63d0cef"
df_test = pd.read_csv(url)
df_test
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg      60      0          20     12      0      0      0      0
# 1       neg      82      0          68     40      0      0      0      0
# 2       neg   66002      2         212    112      0      0      0      0
# 3       neg   59816     na        1010    936      0      0      0      0
# 4       neg    1814     na         156    140      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995   neg   81852     na  2130706432    892      0      0      0      0
# 15996   neg      18      0          52     46      8     26      0      0
# 15997   neg   79636     na        1670   1518      0      0      0      0
# 15998   neg     110     na          36     32      0      0      0      0
# 15999   neg       8      0           6      4      2      2      0      0
#
#       ag_002  ...  ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008  \
# ...

# %%
df_test.shape
# Out:
# (16000, 171)

# %%
df.isna().sum().any()
# Out:
# False

# %%
df_test.isna().sum().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
#encode labels to 0 and 1
le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])
df = df.copy()
df.head()
# Out:
#    class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0      0   76698     na  2130706438    280      0      0      0      0      0
# 1      0   33058     na           0     na      0      0      0      0      0
# 2      0   41040     na         228    100      0      0      0      0      0
# 3      0      12      0          70     66      0     10      0      0      0
# 4      0   60874     na        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# ...

# %%
# Distrubution of class labels in train dataset
df['class'].value_counts()
# Out:
# 0    59000
# 1     1000
# Name: class, dtype: int64

# %%
# Histogram plot of class labels of train dataset
plt.hist(df['class'])
plt.title("Histogram plot of class labels")
# Out:
# Text(0.5, 1.0, 'Histogram plot of class labels')

# %%
print("Percentage of negative class in the given dataset :", (df[df['class']== 0].shape[0] / df.shape[0]) * 100)
print("Percentage of positive class in the given dataset :", (df[df['class']== 1].shape[0] / df.shape[0]) * 100)
# Out:
# Percentage of negative class in the given dataset : 98.33333333333333
# Percentage of positive class in the given dataset : 1.6666666666666667

# %% [markdown]
# ### Observations:
# From the above plot, the given dataset is highly imbalanced. Negative class dominates over the positive class.

# %%
y = df['class']
x = df.drop(['class'],axis = 1,inplace = True)

# %%
df.describe(include='all')
# Out:
#               aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# count   6.000000e+04  60000  60000  60000  60000  60000  60000  60000  60000
# unique           NaN     30   2062   1887    334    419    155    618   2423
# top              NaN     na      0     na      0      0      0      0      0
# freq             NaN  46329   8752  14861  55543  55476  59133  58587  56181
# mean    5.933650e+04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# std     1.454301e+05    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# min     0.000000e+00    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25%     8.340000e+02    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 50%     3.077600e+04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 75%     4.866800e+04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# max     2.746564e+06    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
# Replacing the na and nan values with np.NaN
df.replace(to_replace='nan', value = np.NaN,inplace = True)

df.replace(to_replace = 'na', value = np.NaN, inplace = True)

# %%
# plotting the heatmap of train dataset to visualize the null values.
sns.set(rc={'figure.figsize':(20,20)})
plot = sns.heatmap(df.isnull())
plt.show(plot)

# %%
columns_names = df.columns

# %%
# Plot to indicate the number of missing values in each column of the dataset.
msno.bar(df[columns_names[0:50]])
msno.bar(df[columns_names[50:100]])
msno.bar(df[columns_names[100:150]])
msno.bar(df[columns_names[150:171]])

# %% [markdown]
# ## Removing all the columns where missing values are more than 70%
# * Total number of rows = 60k
# * removing all the columns where more than 70% missing values are present = 60000 x 0.7 = 42000

# %%
# Dropping all the columns where the number of missing values are more than 42K
df.dropna(axis = 1, thresh=42000,inplace= True)

# %%
df.head()
# Out:
#    aa_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002 ag_003 ag_004  \
# 0   76698  2130706438    280      0      0      0      0      0      0  37250
# 1   33058           0    NaN      0      0      0      0      0      0  18254
# 2   41040         228    100      0      0      0      0      0      0   1648
# 3      12          70     66      0     10      0      0      0    318   2212
# 4   60874        1368    458      0      0      0      0      0      0  43752
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# ...

# %%
import pandas as pd
# url = "/home/kiran/Documents/data_science/Scania-Truck-Failures/artifacts/local_data_dirs/aps_failure_training_set.csv"
url = "https://scania-failure-truck.s3.us-east-1.amazonaws.com/data/aps_failure_test_set.csv?response-content-disposition=inline&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEoaCmFwLXNvdXRoLTEiRzBFAiEA6rRDCJU%2Fsc6UZR27QyzLUaYlvH%2B5ypfmACGBeZajQaACIEpqBeRFiwy6XRLHTzbz8p0HAtVHMAoFyklu1fwGPB6MKvYCCEMQABoMNjg0Njc3OTA0NDg3Igzkbo9Rbf%2B65QyrtBYq0wKqO2pDb%2FGRfIDzfic5ILP6atiyGeNm6YtIxn8Mo0OOMBaH5lIWH70Tv4KqtU8BddcOjeF1JBiD3hvRIHL%2B116HYIxj8fbSNTnKt4RQYASnv2JRHyBO0Q4ZSe2RB8Tc4BeuU46hXK%2FALHCitrwy0RApPSKEwlJak43f2XmpQ2FxXkYDLlX7AvZyAFLWXkrmXkFArXbl7ePxMVjaeEN8NjwnFU2Sl7n%2BhygZ4yn460oo2mdSq23dt%2B1qm%2FoYe9tniAUW5jhzQo2BpD%2B8%2FX52ey2ARpRhSBMJzyS7calzCxV8DVpbD6hhNP%2FT2Gva%2BFGvHzGI%2FbH6xyeqA3Vy4rCj5mG4Mu6SEaGNAjLObLToXDwtosrQRgmGqWlmRdMVnHLBB5H4MoenjTF4nWx3UhR1ypVr5p%2F3lk01KrFzps4WzNVd04bXFWPcP4uzxwlRBqvMZLZ16gIwhpiRjgY6swIKS0nJVGCbYXuR5IgHoBVLAkLfV%2B%2Fz2BaOr9fh%2BZYiyfTb8%2BHkLEPh8Q1zwK%2BwY1LJEvCsOZltS3b%2FUyH5XZGLt8F1Uw7urseygqZFISltYnuTwDKE8p1EYDBsqbmz1WpyoX5LpF8SL6nSREiMIKXOEzTGV4rlDj2ZpctedlJDN%2BpE31npFKL1yYGyo%2Bq16g1gAyfzaeE%2BaDI04qMafSbFHFLrJWQO6WSQua%2BA%2BGoIuZPU3H%2Bzqpre6pKfQvII6Y3L07wClChUTzFdiJxlCqztBYczbzJvmu7ubP9TYbitErwTN8XCwpmbd49YQDTYVQb7Eilb9nsHazgFMnozu6AIyxN9xlSPRCNty43uByBOLR3WiGS%2BlgKMYqMPPvEKDEjcoKjVvbzORELMTjH44OS1arl%2F&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211223T104836Z&X-Amz-SignedHeaders=host&X-Amz-Expires=604800&X-Amz-Credential=ASIAZ62P3XBTYRN4SRXC%2F20211223%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=92035adaae9a5adb5c9c0f20d4e506a930415ae75bccc4418865b99e9beb525c"
# url = "https://scania-failure-truck.s3.amazonaws.com/data/aps_failure_test_set.csv"
d = pd.read_csv(url)
d
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg      60      0          20     12      0      0      0      0
# 1       neg      82      0          68     40      0      0      0      0
# 2       neg   66002      2         212    112      0      0      0      0
# 3       neg   59816     na        1010    936      0      0      0      0
# 4       neg    1814     na         156    140      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995   neg   81852     na  2130706432    892      0      0      0      0
# 15996   neg      18      0          52     46      8     26      0      0
# 15997   neg   79636     na        1670   1518      0      0      0      0
# 15998   neg     110     na          36     32      0      0      0      0
# 15999   neg       8      0           6      4      2      2      0      0
#
#       ag_002  ...  ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008  \
# ...
